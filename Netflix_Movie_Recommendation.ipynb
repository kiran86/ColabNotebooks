# %% [markdown]
# <a href="https://colab.research.google.com/github/kiran86/ColabNotebooks/blob/main/Netflix_Movie_Recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Eclat Intuition Model

# %% [markdown]
# ## Installing libraries

# %%
# !pip install apyori
# Out:
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5954 sha256=a911a2e22ab02086de2df2f400417949d5b4d8b09ebd57e700f2b58a0e19a454
#   Stored in directory: /root/.cache/pip/wheels/77/3d/a6/d317a6fb32be58a602b1e8c6b5d6f31f79322da554cad2a5ea
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing dataset

# %%
dataset = pd.read_excel("Dataset_master.xlsx", sheet_name="Netflix Movie Recommendation Ec")
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7465 entries, 0 to 7464
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   The Lord of the rings         7465 non-null   object
#  1   Cinema Paradiso               5732 non-null   object
#  2   Se7en                         4386 non-null   object
#  3   Avengers: Infinity War        3342 non-null   object
#  4   The Shining                   2526 non-null   object
#  5   High and Low                  1861 non-null   object
#  6   Terminator 2: Judgment Day    1366 non-null   object
#  7   Toy Story                     978 non-null    object
#  8   City of God                   653 non-null    object
#  9   Witness for the Prosecution   394 non-null    object
#  10  12 Angry Men                  255 non-null    object
#  11  Whiplash                      153 non-null    object
#  12  Black Panther                 86 non-null     object
#  13  Hamilton                      46 non-null     object
#  14  The Dark Knight               24 non-null     object
#  15  Once Upon a Time in the West  7 non-null      object
#  16  The Great Dictator            3 non-null      object
#  17  Back to the Future            3 non-null      object
#  18  Aliens                        2 non-null      object
#  19  Comedy nights with Kapil      0 non-null      float64
# dtypes: float64(1), object(19)
# memory usage: 1.1+ MB

# %%
transactions = []
for i in range(0, 7465):
  transactions.append([str(dataset.values[i,j]) for j in range(0, 20)])

# %% [markdown]
# ## Eclat

# %% [markdown]
# ### Eclat training on Dataset

# %%
from apyori import apriori
rules = apriori(transactions = transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)

# %% [markdown]
# ### Visualizing

# %% [markdown]
# #### Raw results

# %%
results = list(rules)

# %%
results
# Out:
# [RelationRecord(items=frozenset({'Black Panther', 'Captain America'}), support=0.003348961821835231, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Captain America'}), items_add=frozenset({'Black Panther'}), confidence=0.2450980392156863, lift=5.153962993648164)]),
#  RelationRecord(items=frozenset({'Game of thrones', 'Comedy nights with Kapil'}), support=0.003215003348961822, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Game of thrones'}), items_add=frozenset({'Comedy nights with Kapil'}), confidence=0.2051282051282051, lift=3.1060487855619696)]),
#  RelationRecord(items=frozenset({'Kanan Gill Comedy', 'Comedy nights with Kapil'}), support=0.008037508372404554, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kanan Gill Comedy'}), items_add=frozenset({'Comedy nights with Kapil'}), confidence=0.27149321266968324, lift=4.110946922067313)]),
#  RelationRecord(items=frozenset({'Prision Break', 'Game of thrones'}), support=0.004554588077695914, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Game of thrones'}), items_add=frozenset({'Prision Break'}), confidence=0.29059829059829057, lift=4.831439285782269)]),
#  RelationRecord(items=frozenset({'Harry Potter 2', 'Harry Potter 1'}), support=0.005760214333556598, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Harry Potter 1'}), items_add=frozenset({'Harry Potter 2'}), confidence=0.3675213675213675, lift=4.642211520384109)]),
#  RelationRecord(items=frozenset({'The Lord of the rings', 'Harry Potter 1'}), support=0.005090421969189551, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Harry Potter 1'}), items_add=frozenset({'The Lord of the rings'}), confidence=0.32478632478632474, lift=4.531831615943765)]),
#  RelationRecord(items=frozenset({'Harry Potter 2', 'crimes of grindelwald'}), support=0.005760214333556598, ordered_statistics=[OrderedStatistic(items_base=frozenset({'crimes of grindelwald'}), items_add=frozenset({'Harry Potter 2'}), confidence=0.3006993006993007, lift=3.7981730621324528)]),
#  RelationRecord(items=frozenset({'Interstellar', 'inception'}), support=0.0159410582719357, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Interstellar'}), items_add=frozenset({'inception'}), confidence=0.3216216216216216, lift=3.26209973560517)]),
#  RelationRecord(items=frozenset({'inception', 'The Wolf of Wall Street'}), support=0.0053583389149363695, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Wolf of Wall Street'}), items_add=frozenset({'inception'}), confidence=0.37735849056603776, lift=3.827420016406891)])]

# %% [markdown]
# #### Formatted Display

# %%
def inspect(results):
    movie_1         = [tuple(result[2][0][0])[0] for result in results]
    movie_2         = [tuple(result[2][0][1])[0] for result in results]
    supports    = [result[1] for result in results]
    return list(zip(movie_1, movie_2, supports))
resultsinDataFrame = pd.DataFrame(inspect(results), columns = ['Movie 1', 'Movie 2', 'Support'])

# %%
resultsinDataFrame
# Out:
#                    Movie 1                   Movie 2   Support
# 0          Captain America             Black Panther  0.003349
# 1          Game of thrones  Comedy nights with Kapil  0.003215
# 2        Kanan Gill Comedy  Comedy nights with Kapil  0.008038
# 3          Game of thrones             Prision Break  0.004555
# 4           Harry Potter 1            Harry Potter 2  0.005760
# 5           Harry Potter 1     The Lord of the rings  0.005090
# 6    crimes of grindelwald            Harry Potter 2  0.005760
# 7             Interstellar                 inception  0.015941
# 8  The Wolf of Wall Street                 inception  0.005358

# %%
resultsinDataFrame.nlargest(n = 10, columns = 'Support')
# Out:
#                    Movie 1                   Movie 2   Support
# 7             Interstellar                 inception  0.015941
# 2        Kanan Gill Comedy  Comedy nights with Kapil  0.008038
# 6    crimes of grindelwald            Harry Potter 2  0.005760
# 4           Harry Potter 1            Harry Potter 2  0.005760
# 8  The Wolf of Wall Street                 inception  0.005358
# 5           Harry Potter 1     The Lord of the rings  0.005090
# 3          Game of thrones             Prision Break  0.004555
# 0          Captain America             Black Panther  0.003349
# 1          Game of thrones  Comedy nights with Kapil  0.003215
